# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %%
movies=pd.read_csv('movies.csv')
movies
# Out:
#        movieId                                title  \
# 0            1                     Toy Story (1995)
# 1            2                       Jumanji (1995)
# 2            3              Grumpier Old Men (1995)
# 3            4             Waiting to Exhale (1995)
# 4            5   Father of the Bride Part II (1995)
# ...        ...                                  ...
# 10324   146684        Cosmic Scrat-tastrophe (2015)
# 10325   146878           Le Grand Restaurant (1966)
# 10326   148238       A Very Murray Christmas (2015)
# 10327   148626                 The Big Short (2015)
# 10328   149532  Marco Polo: One Hundred Eyes (2015)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 10324                    Animation|Children|Comedy
# 10325                                       Comedy
# 10326                                       Comedy
# 10327                                        Drama
# 10328                           (no genres listed)
#
# [10329 rows x 3 columns]

# %%
ratings=pd.read_csv('ratings.csv')
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1       16     4.0  1217897793
# 1            1       24     1.5  1217895807
# 2            1       32     4.0  1217896246
# 3            1       47     4.0  1217896556
# 4            1       50     4.0  1217896523
# ...        ...      ...     ...         ...
# 105334     668   142488     4.0  1451535844
# 105335     668   142507     3.5  1451535889
# 105336     668   143385     4.0  1446388585
# 105337     668   144976     2.5  1448656898
# 105338     668   148626     4.5  1451148148
#
# [105339 rows x 4 columns]

# %%
final= pd.merge(movies,ratings,on='movieId')
final
# Out:
#         movieId                                title  \
# 0             1                     Toy Story (1995)
# 1             1                     Toy Story (1995)
# 2             1                     Toy Story (1995)
# 3             1                     Toy Story (1995)
# 4             1                     Toy Story (1995)
# ...         ...                                  ...
# 105334   148238       A Very Murray Christmas (2015)
# 105335   148626                 The Big Short (2015)
# 105336   148626                 The Big Short (2015)
# 105337   148626                 The Big Short (2015)
# 105338   149532  Marco Polo: One Hundred Eyes (2015)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       2     5.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy       8     5.0
# 3       Adventure|Animation|Children|Comedy|Fantasy      11     4.0
# 4       Adventure|Animation|Children|Comedy|Fantasy      14     4.0
# ...                                             ...     ...     ...
# 105334                                       Comedy     475     3.0
# 105335                                        Drama     458     4.0
# 105336                                        Drama     576     4.5
# 105337                                        Drama     668     4.5
# 105338                           (no genres listed)     475     4.0
#
#          timestamp
# 0        859046895
# 1       1303501039
# 2        858610933
# 3        850815810
# 4        851766286
# ...            ...
# 105334  1451213043
# 105335  1452014749
# 105336  1451687664
# 105337  1451148148
# 105338  1451223429
#
# [105339 rows x 6 columns]

# %%
final.isna().sum()
# Out:
# movieId      0
# title        0
# genres       0
# userId       0
# rating       0
# timestamp    0
# dtype: int64

# %%
final.isnull().sum()
# Out:
# movieId      0
# title        0
# genres       0
# userId       0
# rating       0
# timestamp    0
# dtype: int64

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105339 entries, 0 to 105338
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   movieId    105339 non-null  int64
#  1   title      105339 non-null  object
#  2   genres     105339 non-null  object
#  3   userId     105339 non-null  int64
#  4   rating     105339 non-null  float64
#  5   timestamp  105339 non-null  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 4.8+ MB

# %%
final=final[['title','genres','rating']]

# %%
final
# Out:
#                                       title  \
# 0                          Toy Story (1995)
# 1                          Toy Story (1995)
# 2                          Toy Story (1995)
# 3                          Toy Story (1995)
# 4                          Toy Story (1995)
# ...                                     ...
# 105334       A Very Murray Christmas (2015)
# 105335                 The Big Short (2015)
# 105336                 The Big Short (2015)
# 105337                 The Big Short (2015)
# 105338  Marco Polo: One Hundred Eyes (2015)
#
#                                              genres  rating
# 0       Adventure|Animation|Children|Comedy|Fantasy     5.0
# 1       Adventure|Animation|Children|Comedy|Fantasy     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy     5.0
# 3       Adventure|Animation|Children|Comedy|Fantasy     4.0
# 4       Adventure|Animation|Children|Comedy|Fantasy     4.0
# ...                                             ...     ...
# 105334                                       Comedy     3.0
# 105335                                        Drama     4.0
# 105336                                        Drama     4.5
# 105337                                        Drama     4.5
# 105338                           (no genres listed)     4.0
#
# [105339 rows x 3 columns]

# %%
data=pd.read_csv('Human_vital_signs_R.csv')
data
# Out:
#        Unnamed: 0  Time (s)   HR (BPM)   RESP (BPM)   SpO2 (%)  TEMP (*C)  \
# 0               0         0       94.0         21.0       97.0       36.2
# 1               1         1       94.0         25.0       97.0       36.2
# 2               2         2      101.0         25.0       93.0       38.0
# 3               3         3       55.0         11.0      100.0       35.0
# 4               4         4       93.0         26.0       95.0       37.0
# ...           ...       ...        ...          ...        ...        ...
# 25488         476       476       56.0         12.0      101.0       33.0
# 25489         477       477       94.0         25.0       98.0       36.4
# 25490         478       478       94.0         21.0       97.0       36.2
# 25491         479       479       93.0         27.0       95.0       37.0
# 25492         480       480      102.0         25.0       92.0       37.0
#
#          OUTPUT
# 0        Normal
# 1        Normal
# 2      Abnormal
# 3      Abnormal
# 4        Normal
# ...         ...
# 25488  Abnormal
# 25489    Normal
# 25490    Normal
# 25491    Normal
# 25492  Abnormal
#
# [25493 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25493 entries, 0 to 25492
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   25493 non-null  int64
#  1   Time (s)     25493 non-null  int64
#  2    HR (BPM)    25488 non-null  float64
#  3    RESP (BPM)  25346 non-null  float64
#  4    SpO2 (%)    25366 non-null  float64
#  5   TEMP (*C)    25493 non-null  float64
#  6   OUTPUT       25493 non-null  object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 1.4+ MB

# %%
data.rename(columns={'Unnamed: 0':'userid'},inplace=True)

# %%
data
# Out:
#        userid  Time (s)   HR (BPM)   RESP (BPM)   SpO2 (%)  TEMP (*C)  \
# 0           0         0       94.0         21.0       97.0       36.2
# 1           1         1       94.0         25.0       97.0       36.2
# 2           2         2      101.0         25.0       93.0       38.0
# 3           3         3       55.0         11.0      100.0       35.0
# 4           4         4       93.0         26.0       95.0       37.0
# ...       ...       ...        ...          ...        ...        ...
# 25488     476       476       56.0         12.0      101.0       33.0
# 25489     477       477       94.0         25.0       98.0       36.4
# 25490     478       478       94.0         21.0       97.0       36.2
# 25491     479       479       93.0         27.0       95.0       37.0
# 25492     480       480      102.0         25.0       92.0       37.0
#
#          OUTPUT
# 0        Normal
# 1        Normal
# 2      Abnormal
# 3      Abnormal
# 4        Normal
# ...         ...
# 25488  Abnormal
# 25489    Normal
# 25490    Normal
# 25491    Normal
# 25492  Abnormal
#
# [25493 rows x 7 columns]

# %%
data
# Out:
#        userid  Time (s)   HR (BPM)   RESP (BPM)   SpO2 (%)  TEMP (*C)  \
# 0           0         0       94.0         21.0       97.0       36.2
# 1           1         1       94.0         25.0       97.0       36.2
# 2           2         2      101.0         25.0       93.0       38.0
# 3           3         3       55.0         11.0      100.0       35.0
# 4           4         4       93.0         26.0       95.0       37.0
# ...       ...       ...        ...          ...        ...        ...
# 25488     476       476       56.0         12.0      101.0       33.0
# 25489     477       477       94.0         25.0       98.0       36.4
# 25490     478       478       94.0         21.0       97.0       36.2
# 25491     479       479       93.0         27.0       95.0       37.0
# 25492     480       480      102.0         25.0       92.0       37.0
#
#          OUTPUT
# 0        Normal
# 1        Normal
# 2      Abnormal
# 3      Abnormal
# 4        Normal
# ...         ...
# 25488  Abnormal
# 25489    Normal
# 25490    Normal
# 25491    Normal
# 25492  Abnormal
#
# [25493 rows x 7 columns]

# %%
data.isna().sum()
# Out:
# userid           0
# Time (s)         0
#  HR (BPM)        5
#  RESP (BPM)    147
#  SpO2 (%)      127
# TEMP (*C)        0
# OUTPUT           0
# dtype: int64

# %%
df=data.dropna()

# %%
df.isna().sum()
# Out:
# userid         0
# Time (s)       0
#  HR (BPM)      0
#  RESP (BPM)    0
#  SpO2 (%)      0
# TEMP (*C)      0
# OUTPUT         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# userid         0
# Time (s)       0
#  HR (BPM)      0
#  RESP (BPM)    0
#  SpO2 (%)      0
# TEMP (*C)      0
# OUTPUT         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25214 entries, 0 to 25492
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   userid       25214 non-null  int64
#  1   Time (s)     25214 non-null  int64
#  2    HR (BPM)    25214 non-null  float64
#  3    RESP (BPM)  25214 non-null  float64
#  4    SpO2 (%)    25214 non-null  float64
#  5   TEMP (*C)    25214 non-null  float64
#  6   OUTPUT       25214 non-null  object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 1.5+ MB

# %%
df=df.drop(['Time (s)'],axis=1)

# %%
df
# Out:
#        userid   HR (BPM)   RESP (BPM)   SpO2 (%)  TEMP (*C)    OUTPUT
# 0           0       94.0         21.0       97.0       36.2    Normal
# 1           1       94.0         25.0       97.0       36.2    Normal
# 2           2      101.0         25.0       93.0       38.0  Abnormal
# 3           3       55.0         11.0      100.0       35.0  Abnormal
# 4           4       93.0         26.0       95.0       37.0    Normal
# ...       ...        ...          ...        ...        ...       ...
# 25488     476       56.0         12.0      101.0       33.0  Abnormal
# 25489     477       94.0         25.0       98.0       36.4    Normal
# 25490     478       94.0         21.0       97.0       36.2    Normal
# 25491     479       93.0         27.0       95.0       37.0    Normal
# 25492     480      102.0         25.0       92.0       37.0  Abnormal
#
# [25214 rows x 6 columns]

# %%
# Merge datasets based on a common identifier (e.g., userId or index)
data = pd.merge(final,df, left_index=True, right_index=True)
data
# Out:
#                                  title  \
# 0                     Toy Story (1995)
# 1                     Toy Story (1995)
# 2                     Toy Story (1995)
# 3                     Toy Story (1995)
# 4                     Toy Story (1995)
# ...                                ...
# 25488  Bedknobs and Broomsticks (1971)
# 25489       Alice in Wonderland (1951)
# 25490       Alice in Wonderland (1951)
# 25491       Alice in Wonderland (1951)
# 25492       Alice in Wonderland (1951)
#
#                                              genres  rating  userid  \
# 0       Adventure|Animation|Children|Comedy|Fantasy     5.0       0
# 1       Adventure|Animation|Children|Comedy|Fantasy     4.0       1
# 2       Adventure|Animation|Children|Comedy|Fantasy     5.0       2
# 3       Adventure|Animation|Children|Comedy|Fantasy     4.0       3
# 4       Adventure|Animation|Children|Comedy|Fantasy     4.0       4
# ...                                             ...     ...     ...
# 25488                    Adventure|Children|Musical     5.0     476
# 25489  Adventure|Animation|Children|Fantasy|Musical     2.5     477
# 25490  Adventure|Animation|Children|Fantasy|Musical     3.5     478
# 25491  Adventure|Animation|Children|Fantasy|Musical     5.0     479
# 25492  Adventure|Animation|Children|Fantasy|Musical     4.0     480
#
#         HR (BPM)   RESP (BPM)   SpO2 (%)  TEMP (*C)    OUTPUT
# 0           94.0         21.0       97.0       36.2    Normal
# 1           94.0         25.0       97.0       36.2    Normal
# 2          101.0         25.0       93.0       38.0  Abnormal
# 3           55.0         11.0      100.0       35.0  Abnormal
# 4           93.0         26.0       95.0       37.0    Normal
# ...          ...          ...        ...        ...       ...
# 25488       56.0         12.0      101.0       33.0  Abnormal
# 25489       94.0         25.0       98.0       36.4    Normal
# 25490       94.0         21.0       97.0       36.2    Normal
# 25491       93.0         27.0       95.0       37.0    Normal
# 25492      102.0         25.0       92.0       37.0  Abnormal
#
# [25214 rows x 9 columns]

# %%
data.to_csv('final.csv', index=False)

# %%
data = data.drop(columns=['userid', 'OUTPUT'])

# %%
data
# Out:
#                                  title  \
# 0                     Toy Story (1995)
# 1                     Toy Story (1995)
# 2                     Toy Story (1995)
# 3                     Toy Story (1995)
# 4                     Toy Story (1995)
# ...                                ...
# 25488  Bedknobs and Broomsticks (1971)
# 25489       Alice in Wonderland (1951)
# 25490       Alice in Wonderland (1951)
# 25491       Alice in Wonderland (1951)
# 25492       Alice in Wonderland (1951)
#
#                                              genres  rating   HR (BPM)  \
# 0       Adventure|Animation|Children|Comedy|Fantasy     5.0       94.0
# 1       Adventure|Animation|Children|Comedy|Fantasy     4.0       94.0
# 2       Adventure|Animation|Children|Comedy|Fantasy     5.0      101.0
# 3       Adventure|Animation|Children|Comedy|Fantasy     4.0       55.0
# 4       Adventure|Animation|Children|Comedy|Fantasy     4.0       93.0
# ...                                             ...     ...        ...
# 25488                    Adventure|Children|Musical     5.0       56.0
# 25489  Adventure|Animation|Children|Fantasy|Musical     2.5       94.0
# 25490  Adventure|Animation|Children|Fantasy|Musical     3.5       94.0
# 25491  Adventure|Animation|Children|Fantasy|Musical     5.0       93.0
# 25492  Adventure|Animation|Children|Fantasy|Musical     4.0      102.0
#
#         RESP (BPM)   SpO2 (%)  TEMP (*C)
# 0             21.0       97.0       36.2
# 1             25.0       97.0       36.2
# 2             25.0       93.0       38.0
# 3             11.0      100.0       35.0
# 4             26.0       95.0       37.0
# ...            ...        ...        ...
# 25488         12.0      101.0       33.0
# 25489         25.0       98.0       36.4
# 25490         21.0       97.0       36.2
# 25491         27.0       95.0       37.0
# 25492         25.0       92.0       37.0
#
# [25214 rows x 7 columns]

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity


# Preprocess vitals data: Normalize or standardize
vitals_columns = data.iloc[:,3:].columns.tolist()
scaler = StandardScaler()
data[vitals_columns] = scaler.fit_transform(data[vitals_columns])

# Aggregate the vitals data and ratings for each movie
movie_profiles = data.groupby(['title', 'genres']).mean().reset_index()

# Create a user profile by averaging the vitals data and ratings
user_profile = data[vitals_columns].mean().values.reshape(1, -1)

# Compute the cosine similarity between the user profile and movie profiles
movie_vitals = movie_profiles[vitals_columns].values
similarity_scores = cosine_similarity(movie_vitals, user_profile).flatten()

# Add similarity scores to the movie profiles
movie_profiles['similarity_score'] = similarity_scores

# Recommend top 10 movies based on similarity scores
recommended_movies = movie_profiles.sort_values(by='similarity_score', ascending=False).head(10)
print('Recommended Movies:')
print(recommended_movies[['title', 'genres', 'similarity_score']])
# Out:
# Recommended Movies:
#                                title                 genres  similarity_score
# 529                 My Family (1995)                  Drama      2.108039e-15
# 524       Murder in the First (1995)         Drama|Thriller      2.104808e-15
# 539      Natural Born Killers (1994)  Action|Crime|Thriller      2.071693e-15
# 497            Miami Rhapsody (1995)                 Comedy      2.042312e-15
# 553             Nobody's Fool (1994)   Comedy|Drama|Romance      2.034515e-15
# 340                      Heat (1995)  Action|Crime|Thriller      1.996406e-15
# 668      Seven (a.k.a. Se7en) (1995)       Mystery|Thriller      1.982601e-15
# 77                Being Human (1993)                  Drama      1.977276e-15
# 78   Beverly Hillbillies, The (1993)                 Comedy      1.977115e-15
# 540                      Nell (1994)                  Drama      1.972425e-15

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity


# Preprocess vitals data: Normalize or standardize
vitals_columns = data.iloc[:,3:].columns.tolist()
scaler = StandardScaler()
data[vitals_columns] = scaler.fit_transform(data[vitals_columns])

# Aggregate the vitals data and ratings for each movie
movie_profiles = data.groupby(['title', 'genres']).mean().reset_index()

# Function to take user vitals input and recommend movies
def recommend_movies_based_on_vitals(hr, resp, spo2, temp, top_n=10):
    # Normalize the user input vitals
    user_vitals = scaler.transform([[hr, resp, spo2, temp]])

    # Compute the cosine similarity between the user profile and movie profiles
    movie_vitals = movie_profiles[vitals_columns].values
    similarity_scores = cosine_similarity(movie_vitals, user_vitals).flatten()

    # Add similarity scores to the movie profiles
    movie_profiles['similarity_score'] = similarity_scores

    # Recommend top movies based on similarity scores
    recommended_movies = movie_profiles.sort_values(by='similarity_score', ascending=False).head(top_n)
    return recommended_movies[['title', 'genres', 'similarity_score']]

# Example usage
if __name__ == "__main__":
    # Example user input
    hr = float(input("Enter your Heart Rate (BPM): "))
    resp = float(input("Enter your Respiratory Rate (BPM): "))
    spo2 = float(input("Enter your SpO2 (%): "))
    temp = float(input("Enter your Temperature (*C): "))

    # Get movie recommendations based on user vitals
    recommended_movies = recommend_movies_based_on_vitals(hr, resp, spo2, temp)
    print("\nRecommended Movies:")
    print(recommended_movies)
# Out:
# Enter your Heart Rate (BPM): 120
# Enter your Respiratory Rate (BPM): 32
# Enter your SpO2 (%): 25
# Enter your Temperature (*C): 37
#
# Recommended Movies:
#                                                  title                genres  \
# 482                                  Manny & Lo (1996)                 Drama
# 364                                  Houseguest (1994)                Comedy
# 756                                   Threesome (1994)        Comedy|Romance
# 687                                 Small Faces (1996)                 Drama
# 368                                 Hunted, The (1995)                Action
# 372                                        I.Q. (1994)        Comedy|Romance
# 388                      It Could Happen to You (1994)  Comedy|Drama|Romance
# 374                            Immortal Beloved (1994)         Drama|Romance
# 346                Heavyweights (Heavy Weights) (1995)       Children|Comedy
# 386  Interview with the Vampire: The Vampire Chroni...          Drama|Horror
#
#      similarity_score
# 482          0.993830
# 364          0.989827
# 756          0.987664
# 687          0.987605
# 368          0.986560
# 372          0.985415
# 388          0.977044
# 374          0.976446
# 346          0.976338
# 386          0.974400
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# %%writefile app.py
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
import streamlit as st

# Load the dataset
data = pd.read_csv('final.csv')

# Preprocess vitals data: Normalize or standardize
vitals_columns = data.iloc[:,3:].columns.tolist()
scaler = StandardScaler()
data[vitals_columns] = scaler.fit_transform(data[vitals_columns])

# Aggregate the vitals data and ratings for each movie
movie_profiles = data.groupby(['title', 'genres']).mean().reset_index()

# Function to take user vitals input and recommend movies
def recommend_movies_based_on_vitals(hr, resp, spo2, temp, top_n=10):
    # Normalize the user input vitals
    user_vitals = scaler.transform([[hr, resp, spo2, temp]])

    # Compute the cosine similarity between the user profile and movie profiles
    movie_vitals = movie_profiles[vitals_columns].values
    similarity_scores = cosine_similarity(movie_vitals, user_vitals).flatten()

    # Add similarity scores to the movie profiles
    movie_profiles['similarity_score'] = similarity_scores

    # Recommend top movies based on similarity scores
    recommended_movies = movie_profiles.sort_values(by='similarity_score', ascending=False).head(top_n)
    return recommended_movies[['title', 'genres', 'similarity_score']]

# Streamlit application
st.title("Vitals-Based Movie Recommendation System")

st.header("Enter your vitals:")
hr = st.number_input("Heart Rate (BPM):", min_value=0, max_value=200, value=70)
resp = st.number_input("Respiratory Rate (BPM):", min_value=0, max_value=50, value=20)
spo2 = st.number_input("SpO2 (%):", min_value=0, max_value=100, value=95)
temp = st.number_input("Temperature (*C):", min_value=30.0, max_value=45.0, value=36.5)

if st.button("Get Recommendations"):
    recommended_movies = recommend_movies_based_on_vitals(hr, resp, spo2, temp)
    st.subheader("Recommended Movies:")
    for index, row in recommended_movies.iterrows():
        st.write(f"{row['title']} ({row['genres']}) - Similarity Score: {row['similarity_score']:.4f}")
# Out:
# Overwriting app.py

# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 21.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 18.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 56.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.4 MB/s eta 0:00:00

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 35.247.49.60

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.247.49.60:8501
#
# npx: installed 22 in 7.233s
# your url is: https://nine-doodles-itch.loca.lt
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
#   Stopping...
# ^C

# %%
# %%writefile app1.py
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
import streamlit as st

# Load the dataset
data = pd.read_csv('final.csv')

# Preprocess vitals data: Normalize or standardize
vitals_columns = data.iloc[:,3:].columns.tolist()
scaler = StandardScaler()
data[vitals_columns] = scaler.fit_transform(data[vitals_columns])

# Aggregate the vitals data and ratings for each movie
movie_profiles = data.groupby(['title', 'genres']).mean().reset_index()

# Function to take user vitals input and recommend movies
def recommend_movies_based_on_vitals(hr, resp, spo2, temp, top_n=10):
    # Normalize the user input vitals
    user_vitals = scaler.transform([[hr, resp, spo2, temp]])

    # Compute the cosine similarity between the user profile and movie profiles
    movie_vitals = movie_profiles[vitals_columns].values
    similarity_scores = cosine_similarity(movie_vitals, user_vitals).flatten()

    # Add similarity scores to the movie profiles
    movie_profiles['similarity_score'] = similarity_scores

    # Recommend top movies based on similarity scores
    recommended_movies = movie_profiles.sort_values(by='similarity_score', ascending=False).head(top_n)
    return recommended_movies[['title', 'genres', 'similarity_score']]

# Function to recommend movies based on a selected movie
def recommend_movies_based_on_selection(selected_movie, top_n=10):
    # Get the movie profile for the selected movie
    selected_movie_profile = movie_profiles[movie_profiles['title'] == selected_movie][vitals_columns].values

    # Compute cosine similarity between the selected movie and all other movies
    similarity_scores = cosine_similarity(movie_profiles[vitals_columns].values, selected_movie_profile).flatten()

    # Add similarity scores to the movie profiles
    movie_profiles['similarity_score'] = similarity_scores

    # Recommend top movies based on similarity scores
    recommended_movies = movie_profiles.sort_values(by='similarity_score', ascending=False).head(top_n)
    return recommended_movies[['title', 'genres', 'similarity_score']]

# Streamlit application
st.title("Vitals-Based Movie Recommendation System")

# Sidebar for vitals input
st.sidebar.header("Enter your vitals:")
hr = st.sidebar.number_input("Heart Rate (BPM):", min_value=0, max_value=200, value=70)
resp = st.sidebar.number_input("Respiratory Rate (BPM):", min_value=0, max_value=50, value=20)
spo2 = st.sidebar.number_input("SpO2 (%):", min_value=0, max_value=100, value=95)
temp = st.sidebar.number_input("Temperature (*C):", min_value=30.0, max_value=45.0, value=36.5)

# Button to get initial movie recommendations based on vitals
if st.sidebar.button("Get Recommendations"):
    recommended_movies = recommend_movies_based_on_vitals(hr, resp, spo2, temp)
    st.sidebar.subheader("Recommended Movies:")
    for index, row in recommended_movies.iterrows():
        st.sidebar.write(f"{row['title']} ({row['genres']}) - Similarity Score: {row['similarity_score']:.4f}")

# Section for selecting a movie from initial recommendations
selected_movie = st.selectbox("Select a movie from the recommendations above:", recommended_movies['title'].tolist() if 'recommended_movies' in locals() else [])

# Button to get recommendations based on the selected movie
if selected_movie:
    st.subheader(f"You selected: {selected_movie}")
    st.write("Fetching recommendations based on your selection...")

    # Get recommendations based on selected movie
    recommendations_for_selected_movie = recommend_movies_based_on_selection(selected_movie)
    st.subheader("Recommended Movies Based on Your Selection:")
    for index, row in recommendations_for_selected_movie.iterrows():
        st.write(f"{row['title']} ({row['genres']}) - Similarity Score: {row['similarity_score']:.4f}")
# Out:
# Overwriting app1.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.247.49.60:8501
#
# npx: installed 22 in 3.842s
# your url is: https://smooth-turtles-help.loca.lt
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
#   Stopping...
# ^C

# %%
# %%writefile app.py
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
import streamlit as st

# Load the dataset
data = pd.read_csv('final.csv')

# Preprocess vitals data: Normalize or standardize
vitals_columns = data.iloc[:,3:].columns.tolist()
scaler = StandardScaler()
data[vitals_columns] = scaler.fit_transform(data[vitals_columns])

# Aggregate the vitals data and ratings for each movie
movie_profiles = data.groupby(['title', 'genres']).mean().reset_index()

# Function to take user vitals input and recommend movies
def recommend_movies_based_on_vitals(hr, resp, spo2, temp, top_n=10):
    # Normalize the user input vitals
    user_vitals = scaler.transform([[hr, resp, spo2, temp]])

    # Compute the cosine similarity between the user profile and movie profiles
    movie_vitals = movie_profiles[vitals_columns].values
    similarity_scores = cosine_similarity(movie_vitals, user_vitals).flatten()

    # Add similarity scores to the movie profiles
    movie_profiles['similarity_score'] = similarity_scores

    # Recommend top movies based on similarity scores
    recommended_movies = movie_profiles.sort_values(by='similarity_score', ascending=False).head(top_n)
    return recommended_movies[['title', 'genres', 'similarity_score']]

# Function to recommend movies based on an input movie
def recommend_movies_based_on_movie(input_movie, top_n=10):
    # Find the movie profile for the input movie
    movie_profile = movie_profiles[movie_profiles['title'] == input_movie]
    if movie_profile.empty:
        return pd.DataFrame()  # Return empty DataFrame if movie not found

    # Compute the cosine similarity between the input movie and all other movies
    movie_vitals = movie_profiles[vitals_columns].values
    input_movie_vitals = movie_profile[vitals_columns].values
    similarity_scores = cosine_similarity(movie_vitals, input_movie_vitals).flatten()

    # Add similarity scores to the movie profiles
    movie_profiles['similarity_score'] = similarity_scores

    # Recommend top movies based on similarity scores
    recommended_movies = movie_profiles.sort_values(by='similarity_score', ascending=False).head(top_n + 1)
    recommended_movies = recommended_movies[recommended_movies['title'] != input_movie]  # Exclude the input movie
    return recommended_movies[['title', 'genres', 'similarity_score']]

# Streamlit application
st.title("Vitals-Based and Movie-Based Movie Recommendation System")

# Vitals-based recommendation
st.header("Enter your vitals to get movie recommendations:")
hr = st.number_input("Heart Rate (BPM):", min_value=0, max_value=200, value=70)
resp = st.number_input("Respiratory Rate (BPM):", min_value=0, max_value=50, value=20)
spo2 = st.number_input("SpO2 (%):", min_value=0, max_value=100, value=95)
temp = st.number_input("Temperature (*C):", min_value=30.0, max_value=45.0, value=36.5)

if st.button("Get Recommendations Based on Vitals"):
    recommended_movies = recommend_movies_based_on_vitals(hr, resp, spo2, temp)
    st.subheader("Recommended Movies Based on Vitals:")
    for index, row in recommended_movies.iterrows():
        st.write(f"{row['title']} ({row['genres']}) - Similarity Score: {row['similarity_score']:.4f}")

# Movie-based recommendation
st.header("Enter a movie name to get next movie recommendations:")
input_movie = st.text_input("Movie Name:")

if st.button("Get Recommendations Based on Movie"):
    recommended_movies = recommend_movies_based_on_movie(input_movie)
    if recommended_movies.empty:
        st.write("Movie not found. Please check the movie name and try again.")
    else:
        st.subheader("Recommended Movies Based on Movie:")
        for index, row in recommended_movies.iterrows():
            st.write(f"{row['title']} ({row['genres']}) - Similarity Score: {row['similarity_score']:.4f}")
# Out:
# Overwriting app.py
